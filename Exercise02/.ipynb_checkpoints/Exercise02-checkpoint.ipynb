# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 2</span>
# ### Bigoni Stefano, 961886
# ### Exercize 02.1

# %% [markdown]
# In this Exercise I compute the integral
# $$I = \int_0^1 \frac{\pi}{2}\cos(\pi x/2) dx = 1$$
# in two ways, sampling a uniform distribution and using the importance sampling technique in the interval $[0,1]$.
# For the second I chose a simple line with normalized area in $[0,1]$ as sampling p.d.f.: $$ p(x) = 2-2x.$$
# ![alt text](imp-sampling.png "Logo Title Text 1")
# The resulting cumulative distribution function is $$F(x) = \int_0^xp(x)dx = 2x-x^2 .$$
# Therefore, if $y$ is a uniformly distributed random variable in $[0,1]$, a random variable $x$ distributed according to $p(x)$ is obtained as $$x = 1-\sqrt{1-y}.$$

# %% [markdown]
# In the plots below are shown the cumulative average values and the correspondent errors for 100 blocks of $10^3$ throws each, for both computation techniques.

# %%
import matplotlib.pyplot as plt
import numpy as np

output = open("uniform.dat","r")
M = int(output.readline())
output.close()

data = np.loadtxt(fname = "uniform.dat",skiprows=1)
r = data[:,0]
err = data[:,1]
N = np.size(r)
x = np.linspace(1,M,N)

data2 = np.loadtxt(fname = "importance.dat",skiprows=1)
r2 = data2[:,0]
err2 = data2[:,1]

fig = plt.figure(figsize=(14,4))

plt.subplot(1,2,1)

plt.errorbar(x,r-1,yerr=err)
plt.title("Uniform sampling")
plt.xlabel("# of throws")
plt.ylabel("$<I>$-1")
plt.ylim([-0.006,0.015])
plt.grid(True)

plt.subplot(1,2,2)

plt.errorbar(x,r2-1,yerr=err2,color='orangered')
plt.title("Importance sampling")
plt.xlabel("# of throws")
#plt.ylabel("$<I>$-1")
plt.ylim([-0.006,0.015])
plt.grid(True)

plt.suptitle("Estimation of $I$")
plt.show()

# %% [markdown]
# 3D Random Walk

# %%
output = open("RWdiscrete.dat","r")
M = int(output.readline())
output.close()

data = np.loadtxt(fname = "RWdiscrete.dat",skiprows=1)
r = data[:,0]
err = data[:,1]
N = np.size(r)
x = np.arange(0,100)

err_sqrt = np.zeros(N)
err_sqrt[0] = 0;
err_sqrt[1:] = (0.5/x[1:]**0.5)*err[1:]


plt.errorbar(x,r**0.5,yerr=err_sqrt)
plt.plot(x,1.22*x**0.5) #fit
plt.grid(True)
plt.xlabel("# of steps N")
plt.ylabel("r (lattice unit)")
plt.legend(["$k\sqrt{N}$","RW"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-a3a2af440588> in <module>
#      13 err_sqrt[0] = 0;
#      14
# ---> 15 plt.errorbar(x,r**0.5,yerr=err_sqrt)
#      16 plt.plot(x,1.22*x**0.5) #fit
#      17 plt.grid(True)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in errorbar(x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, data, **kwargs)
#    2559         lolims=lolims, uplims=uplims, xlolims=xlolims,
#    2560         xuplims=xuplims, errorevery=errorevery, capthick=capthick,
# -> 2561         **({"data": data} if data is not None else {}), **kwargs)
#    2562
#    2563
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3421
#    3422         if yerr is not None:
# -> 3423             lower, upper = extract_err(yerr, y)
#    3424             # select points without upper/lower limits in y and
#    3425             # draw normal errorbars for these points
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in extract_err(err, data)
#    3365                 if len(data) != len(e):
#    3366                     raise ValueError(
# -> 3367                         f"The lengths of the data ({len(data)}) and the "
#    3368                         f"error {len(e)} do not match")
#    3369             low = [v - e for v, e in zip(data, a)]
#
# ValueError: The lengths of the data (100) and the error 99 do not match
